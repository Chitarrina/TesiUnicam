# %%
import os

#Inserire il path del set di dati dove si trovano i comuni
path = "C:/Users/leonn/Documents/Progetti/TesiUnicam/Data/"

#del path ricava una lista di tutti i file e directory
listComuni = os.listdir(path)

#rimuovere dalla lista i file (sono quelli contrassegnati da una estensione ".")
for comune in listComuni:
    if "." in comune or "Output" in comune or "Plot" in comune:
        listComuni.remove(comune)

# %%
#il seguente script stampa tutti i path per arrivare ai file "Istanze.csv"
for comune in listComuni:
    comune = path+comune+"/Istanze.csv"
    print(comune)
# Out:
# C:/Users/leonn/Documents/Progetti/TesiUnicam/Data/Udine/Istanze.csv

# %%
#if not os.path.exists(path+"/Output")
#os.mkdir(path+"/Output")
for comune in listComuni:
    os.mkdir(path+"/Output/"+comune)

# %%
import pandas
import csv
for comune in listComuni:
    print("Sto processando il comune "+comune+"...")
    #blocco 1

    df1 = pandas.read_csv(path+comune+"/" + "Istanze.csv", encoding='ISO-8859-1', low_memory='false')

    df1_droped=df1.drop(['id passo', 'id iter', 'versione iter','desc iter',  'flg iter default', 'area iter', 'id istanza padre', 'id flusso', 'id flusso padre',
                        'id flusso istanza padre', 'id istanza padre', 'id stato', 'ordine generazione', 'stato inizio ms', 'stato fine ms','utente super user','utente internal user' ], axis=1 )
    
    df1_droped = df1_droped.fillna('')

    #blocco 2
    df1_droped['activity'] = df1_droped['tipo stato'].str.cat(df1_droped['desc stato'],sep='_')

    #blocco 3 (quello con piu necessità computazionale)
    # per ottimizzare usare il parallelismo o eventuali librerie di set/map
    labels=df1_droped['activity'] 
    names = {}
    for l in labels:
        names.setdefault(l, len(names)+1)
        df1_droped['coded activity'] = df1_droped['activity'].map(names)

    #blocco 4 (richiede blocco3)
    vec = []
    for i in df1_droped['coded activity'] :
        i=int(i)
        i=i+96
        vec.append(chr(i))
    df1_droped.insert(9, "renamed", vec)

    #blocco 5
    group = df1_droped.groupby('nome iter')  
    for k, gr in group:
        # do your stuff instead of print
        #print(k)
        #print(type(gr)) # This will output <class 'pandas.core.frame.DataFrame'>
        #print(gr)
        # You can save each 'gr' in a csv as follows
        gr.to_csv(path+'/Output/'+comune+'/{}.csv'.format(k))
    print(comune+" processato!\n")
    break
# Out:
# Sto processando il comune Udine...
# Udine processato!

# %%
df1_droped
# Out:
#       id parent iter                 nome iter  id istanza  \
# 0                NaN  Postalizzazione standard           1
# 1                NaN  Postalizzazione standard           1
# 2                NaN  Postalizzazione standard           1
# 3                NaN  Postalizzazione standard           1
# 4                NaN  Postalizzazione standard           1
# ...              ...                       ...         ...
# 3507           172.0  Postalizzazione standard         378
# 3508           172.0  Postalizzazione standard         378
# 3509           172.0  Postalizzazione standard         378
# 3510           172.0  Postalizzazione standard         378
# 3511           172.0  Postalizzazione standard         378
#
#                   desc stato                         tipo stato stato inizio  \
# 0             stato iniziale                                NaN   01/10/2018
# 1            estrai_dati_wkf  instance_handling.info_extraction   01/10/2018
# 2              conf_iniziale                   post_conf_valori   01/10/2018
# 3       Attrattore di errori                                NaN   01/10/2018
# 4               ask_prosegui    simple_interaction.human_choice   01/10/2018
# ...                      ...                                ...          ...
# 3507        verifica_ufficio              data_handling.formula   01/07/2020
# 3508        cond_sped_scelta             data_handling.switcher   01/07/2020
# 3509       scegli_spedizione             post_scelta_spedizione   01/07/2020
# 3510                 pulizia                post_pulizia_finale   01/07/2020
# 3511  annullato o con errori                                NaN   01/07/2020
#
#       stato fine  id utente esecutore utente descrizione renamed  \
# 0     01/10/2018                   13             Utente       a
# 1     01/10/2018                   13             Utente       b
# 2     01/10/2018                   13             Utente       c
# 3     01/10/2018                   13             Utente       a
# 4     01/10/2018                   13             Utente       d
# ...          ...                  ...                ...     ...
# 3507  01/07/2020                   67             Utente       f
# 3508  01/07/2020                   67             Utente       g
# 3509  01/07/2020                   67             Utente       h
# 3510  01/07/2020                   67             Utente       e
# 3511         NaN                   67             Utente       a
#
#                                                activity  coded activity
# 0                                                   NaN               1
# 1     ac_instance_handling.info_extraction_estrai_da...               2
# 2                     ac_post_conf_valori_conf_iniziale               3
# 3                                                   NaN               1
# 4       ac_simple_interaction.human_choice_ask_prosegui               4
# ...                                                 ...             ...
# 3507          ac_data_handling.formula_verifica_ufficio               6
# 3508         ac_data_handling.switcher_cond_sped_scelta               7
# 3509        ac_post_scelta_spedizione_scegli_spedizione               8
# 3510                     ac_post_pulizia_finale_pulizia               5
# 3511                                                NaN               1
#
# [3512 rows x 12 columns]

# %%
of print
        #print(k)
        #print(type(gr)) # This will output <class 'pandas.core.frame.DataFrame'>
        #print(gr)
        # You can save each 'gr' in a csv as follows
        gr.to_csv(path+'/Output/'+comune+'/{}.csv'.format(k))
    print(comune+" processato!\n")
